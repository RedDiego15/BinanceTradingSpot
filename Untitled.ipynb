# %% [markdown]
# <h1>No olvidar cambiar la fecha de lectura del csv mas reciente</h1>

# %%
import pandas as pd

# %%
def createIndex(x):
    key = str(x['Date(UTC)'].year),str(x['Date(UTC)'].strftime("%H:%M:%S")),str(x['Date(UTC)'].day),x['Fee Coin'],str(x['Amount'])
    return key

# %%
#Amount = cantidad crypto que obtuve
#total = dinero invertido
#Sell_Porcent = porcent of position selled
#price = precio al que compre
#rest valua es el amount de crypto que queda luego de haber vendido un determinado porcentaje de esa posicion 

#df DEBE SER EL OUTPUT 
#df = pd.read_csv("../BinanceDataSet/Exportar historial de operaciones-2022-06-07.csv")
df = pd.read_csv("../Output/CLEAN_data_10-06-2023.csv")
df['Date(UTC)'] = pd.to_datetime(df['Date(UTC)']) 
df['key'] = df.apply(createIndex,axis=1)
df['rest_value'] = df['Amount'] - df['Amount'] * (df['sell_Porcent']/100) 


# #EL RDF DEBE SER DESDE LA FECHA DEL ULTIMO REPORTE HASTA EL DIA anterior 

rdf = pd.read_csv("../BinanceDataSet/Export Trade History-2023-10-11 14_19_00.csv")

rdf['Date(UTC)'] = pd.to_datetime(rdf['Date(UTC)'])
rdf['sell_Porcent'] = 0
rdf['is_Open'] = True
rdf['key'] = rdf.apply(createIndex,axis=1)
rdf['rest_value'] = rdf['Amount'] - rdf['Amount'] * (rdf['sell_Porcent']/100) 
df.head()
# Out:
#             Date(UTC)    Market  Type    Price    Amount      Total  \
# 0 2022-05-16 02:42:00  LUNABUSD   BUY  0.00026  38389.18   9.999997
# 1 2022-06-13 01:34:00   VETBUSD   BUY  0.02487    410.10  10.199187
# 2 2022-11-23 05:28:00  ROSEUSDT  SELL  0.04643    215.40  10.001022
# 3 2022-07-12 01:56:00  ROSEUSDT   BUY  0.04687    215.40  10.095798
# 4 2022-06-12 02:47:00  ROSEUSDT   BUY  0.05515    185.20  10.213780
#
#          Fee Fee Coin  sell_Porcent  is_Open  \
# 0  38.389180     LUNA             0     True
# 1   0.410100      VET             0     True
# 2   0.010001     USDT             0     True
# 3   0.215400     ROSE             0     True
# 4   0.185200     ROSE             0     True
#
#                                     key  rest_value  Unnamed: 12  Unnamed: 13
# 0  (2022, 02:42:00, 16, LUNA, 38389.18)    38389.18          NaN          NaN
# 1      (2022, 01:34:00, 13, VET, 410.1)      410.10          NaN          NaN
# 2     (2022, 05:28:00, 23, USDT, 215.4)      215.40          NaN          NaN
# 3     (2022, 01:56:00, 12, ROSE, 215.4)      215.40          NaN          NaN
# 4     (2022, 02:47:00, 12, ROSE, 185.2)      185.20          NaN          NaN

# %%
rdf.head()
# Out:
#             Date(UTC)   Market Type      Price    Amount    Total  \
# 0 2023-10-11 17:45:04  BTCUSDT  BUY  26610.000   0.00022  5.85420
# 1 2023-10-11 17:16:00  BTCUSDT  BUY  26630.000   0.00019  5.05970
# 2 2023-10-11 16:43:14  BTCUSDT  BUY  26688.000   0.00022  5.87136
# 3 2023-10-11 16:43:13  ETHUSDT  BUY   1555.000   0.00640  9.95200
# 4 2023-10-11 16:39:07  ADAUSDT  BUY      0.247  20.20000  4.98940
#
#             Fee Fee Coin  sell_Porcent  is_Open  \
# 0  2.200000e-07      BTC             0     True
# 1  1.900000e-07      BTC             0     True
# 2  2.200000e-07      BTC             0     True
# 3  6.400000e-06      ETH             0     True
# 4  2.020000e-02      ADA             0     True
#
#                                   key  rest_value
# 0  (2023, 17:45:04, 11, BTC, 0.00022)     0.00022
# 1  (2023, 17:16:00, 11, BTC, 0.00019)     0.00019
# 2  (2023, 16:43:14, 11, BTC, 0.00022)     0.00022
# 3   (2023, 16:43:13, 11, ETH, 0.0064)     0.00640
# 4     (2023, 16:39:07, 11, ADA, 20.2)    20.20000

# %%
df = pd.concat([df,rdf])
df = df.reset_index(drop=True)
df.drop_duplicates(subset=['key'],keep='first',inplace=True)
df = df.loc[df['is_Open']==True]
df
# Out:
#               Date(UTC)    Market  Type        Price       Amount      Total  \
# 0   2022-05-16 02:42:00  LUNABUSD   BUY      0.00026  38389.18000   9.999997
# 1   2022-06-13 01:34:00   VETBUSD   BUY      0.02487    410.10000  10.199187
# 2   2022-11-23 05:28:00  ROSEUSDT  SELL      0.04643    215.40000  10.001022
# 3   2022-07-12 01:56:00  ROSEUSDT   BUY      0.04687    215.40000  10.095798
# 4   2022-06-12 02:47:00  ROSEUSDT   BUY      0.05515    185.20000  10.213780
# ..                  ...       ...   ...          ...          ...        ...
# 578 2023-10-09 08:19:57   DOTUSDT   BUY      3.97000      2.56000  10.163200
# 579 2023-10-08 10:46:47   ETHUSDT   BUY   1620.00000      0.00620  10.044000
# 580 2023-10-06 20:23:33   ETHUSDT  SELL   1646.65000      0.01540  25.358410
# 581 2023-10-06 20:16:12   BTCUSDT  SELL  27959.66000      0.00104  29.078046
# 582 2023-10-06 12:58:21   BTCUSDT   BUY  27226.00000      0.00037  10.073620
#
#               Fee Fee Coin  sell_Porcent  is_Open  \
# 0    3.838918e+01     LUNA             0     True
# 1    4.101000e-01      VET             0     True
# 2    1.000102e-02     USDT             0     True
# 3    2.154000e-01     ROSE             0     True
# 4    1.852000e-01     ROSE             0     True
# ..            ...      ...           ...      ...
# 578  2.560000e-03      DOT             0     True
# 579  6.200000e-06      ETH             0     True
# 580  2.535841e-02     USDT             0     True
# 581  2.907805e-02     USDT             0     True
# 582  3.700000e-07      BTC             0     True
#
#                                       key   rest_value  Unnamed: 12  \
# 0    (2022, 02:42:00, 16, LUNA, 38389.18)  38389.18000          NaN
# 1        (2022, 01:34:00, 13, VET, 410.1)    410.10000          NaN
# 2       (2022, 05:28:00, 23, USDT, 215.4)    215.40000          NaN
# 3       (2022, 01:56:00, 12, ROSE, 215.4)    215.40000          NaN
# 4       (2022, 02:47:00, 12, ROSE, 185.2)    185.20000          NaN
# ..                                    ...          ...          ...
# 578        (2023, 08:19:57, 9, DOT, 2.56)      2.56000          NaN
# 579      (2023, 10:46:47, 8, ETH, 0.0062)      0.00620          NaN
# 580     (2023, 20:23:33, 6, USDT, 0.0154)      0.01540          NaN
# 581    (2023, 20:16:12, 6, USDT, 0.00104)      0.00104          NaN
# 582     (2023, 12:58:21, 6, BTC, 0.00037)      0.00037          NaN
#
#      Unnamed: 13
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 578          NaN
# 579          NaN
# 580          NaN
# 581          NaN
# 582          NaN
#
# [579 rows x 14 columns]

# %%
df.head()
# Out:
#             Date(UTC)    Market  Type    Price    Amount      Total  \
# 0 2022-05-16 02:42:00  LUNABUSD   BUY  0.00026  38389.18   9.999997
# 1 2022-06-13 01:34:00   VETBUSD   BUY  0.02487    410.10  10.199187
# 2 2022-11-23 05:28:00  ROSEUSDT  SELL  0.04643    215.40  10.001022
# 3 2022-07-12 01:56:00  ROSEUSDT   BUY  0.04687    215.40  10.095798
# 4 2022-06-12 02:47:00  ROSEUSDT   BUY  0.05515    185.20  10.213780
#
#          Fee Fee Coin  sell_Porcent  is_Open  \
# 0  38.389180     LUNA             0     True
# 1   0.410100      VET             0     True
# 2   0.010001     USDT             0     True
# 3   0.215400     ROSE             0     True
# 4   0.185200     ROSE             0     True
#
#                                     key  rest_value  Unnamed: 12  Unnamed: 13
# 0  (2022, 02:42:00, 16, LUNA, 38389.18)    38389.18          NaN          NaN
# 1      (2022, 01:34:00, 13, VET, 410.1)      410.10          NaN          NaN
# 2     (2022, 05:28:00, 23, USDT, 215.4)      215.40          NaN          NaN
# 3     (2022, 01:56:00, 12, ROSE, 215.4)      215.40          NaN          NaN
# 4     (2022, 02:47:00, 12, ROSE, 185.2)      185.20          NaN          NaN

# %%
# dfg = df.groupby('Fee Coin').sum()
# dfg
#df['Fee Coin'] == 'BNB'

# %%
adaDf = df.loc[(df['Market']=='ADAUSDT') | (df['Market']=='ADABUSD')]
btcDf = df.loc[(df['Market']=='BTCUSDT') | (df['Market']=='BTCBUSD')]
ethDf = df.loc[(df['Market']=='ETHUSDT') | (df['Market']=='ETHBUSD')]
dotDf = df.loc[(df['Market']=='DOTUSDT') | (df['Market']=='DOTBUSD')]
solDf = df.loc[(df['Market']=='SOLUSDT') | (df['Market']=='SOLBUSD')]
roseDf = df.loc[(df['Market']=='ROSEUSDT') | (df['Market']=='ROSEBUSD')]
bnbDf = df.loc[(df['Market']=='BNBUSDT') | (df['Market']=='BNBBUSD')]



adaDf.head()
# Out:
#              Date(UTC)   Market  Type   Price  Amount     Total       Fee  \
# 14 2022-12-20 16:12:00  ADABUSD  SELL  0.2595    39.9  10.35405  0.000031
# 16 2022-12-16 23:56:00  ADABUSD   BUY  0.2638    40.4  10.65752  0.040400
# 17 2022-12-16 22:34:00  ADAUSDT   BUY  0.2800    36.0  10.08000  0.036000
# 18 2022-12-16 11:32:00  ADAUSDT   BUY  0.2863    35.2  10.07776  0.035200
# 19 2023-01-10 04:01:00  ADABUSD  SELL  0.3141   194.4  61.06104  0.061061
#
#    Fee Coin  sell_Porcent  is_Open                                key  \
# 14      BNB             0     True    (2022, 16:12:00, 20, BNB, 39.9)
# 16      ADA            60     True    (2022, 23:56:00, 16, ADA, 40.4)
# 17      ADA            70     True    (2022, 22:34:00, 16, ADA, 36.0)
# 18      ADA            90     True    (2022, 11:32:00, 16, ADA, 35.2)
# 19     BUSD             0     True  (2023, 04:01:00, 10, BUSD, 194.4)
#
#     rest_value  Unnamed: 12  Unnamed: 13
# 14       39.90          NaN          NaN
# 16       16.16          NaN          NaN
# 17       10.80          NaN          NaN
# 18        3.52          NaN          NaN
# 19      194.40          NaN          NaN

# %%
adaDf = adaDf.loc[adaDf['Type']== 'BUY']
btcDf = btcDf.loc[btcDf['Type']== 'BUY']
ethDf = ethDf.loc[ethDf['Type']== 'BUY']
dotDf = dotDf.loc[dotDf['Type']== 'BUY']
solDf = solDf.loc[solDf['Type']== 'BUY']
roseDf = roseDf.loc[roseDf['Type']== 'BUY']
bnbDf = bnbDf.loc[bnbDf['Type']== 'BUY']

# %%
#Order de mayor a menor 
adaDf = adaDf.sort_values(by='Price')
ethDf = ethDf.sort_values(by='Price')
btcDf = btcDf.sort_values(by='Price')
dotDf = dotDf.sort_values(by='Price')
solDf = solDf.sort_values(by='Price')
roseDf = roseDf.sort_values(by='Price')
bnbDf = bnbDf.sort_values(by='Price')

# %%
#New Index
btcDf = btcDf.reset_index(drop=True)
dotDf = dotDf.reset_index(drop=True)
adaDf = adaDf.reset_index(drop=True)
ethDf = ethDf.reset_index(drop=True)
solDf = solDf.reset_index(drop=True)
roseDf = roseDf.reset_index(drop=True)
bnbDf = bnbDf.reset_index(drop=True)

btcDf
# Out:
#              Date(UTC)   Market Type     Price   Amount      Total  \
# 0  2022-11-09 22:06:00  BTCUSDT  BUY  15650.00  0.00064  10.016000
# 1  2022-12-16 23:11:00  BTCBUSD  BUY  16600.00  0.00061  10.126000
# 2  2022-11-02 22:53:00  BTCUSDT  BUY  20060.00  0.00050  10.030000
# 3  2023-03-10 13:52:00  BTCUSDT  BUY  20215.73  0.00059  11.927281
# 4  2023-02-09 20:19:00  BTCBUSD  BUY  21870.00  0.00046  10.060200
# ..                 ...      ...  ...       ...      ...        ...
# 80 2023-07-06 14:31:00  BTCUSDT  BUY  30023.60  0.00033   9.907788
# 81 2023-07-14 18:53:00  BTCUSDT  BUY  30174.01  0.00033   9.957423
# 82 2023-07-14 20:54:00  BTCUSDT  BUY  30190.62  0.00033   9.962905
# 83 2023-07-14 18:31:00  BTCUSDT  BUY  30200.00  0.00034  10.268000
# 84 2023-07-14 18:21:00  BTCUSDT  BUY  30530.62  0.00033  10.075105
#
#              Fee Fee Coin  sell_Porcent  is_Open  \
# 0   0.000000e+00      BNB            90     True
# 1   0.000000e+00      BNB            90     True
# 2   0.000000e+00      BNB            50     True
# 3   0.000000e+00      BNB            60     True
# 4   0.000000e+00      BNB            60     True
# ..           ...      ...           ...      ...
# 80  3.300000e-07      BTC            70     True
# 81  3.300000e-07      BTC            20     True
# 82  3.300000e-07      BTC            30     True
# 83  3.400000e-07      BTC            60     True
# 84  3.300000e-07      BTC             0     True
#
#                                    key  rest_value  Unnamed: 12  Unnamed: 13
# 0    (2022, 22:06:00, 9, BNB, 0.00064)    0.000064          NaN          NaN
# 1   (2022, 23:11:00, 16, BNB, 0.00061)    0.000061          NaN          NaN
# 2     (2022, 22:53:00, 2, BNB, 0.0005)    0.000250          NaN          NaN
# 3   (2023, 13:52:00, 10, BNB, 0.00059)    0.000236          NaN          NaN
# 4    (2023, 20:19:00, 9, BNB, 0.00046)    0.000184          NaN          NaN
# ..                                 ...         ...          ...          ...
# 80   (2023, 14:31:00, 6, BTC, 0.00033)    0.000099          NaN          NaN
# 81  (2023, 18:53:00, 14, BTC, 0.00033)    0.000264          NaN          NaN
# 82  (2023, 20:54:00, 14, BTC, 0.00033)    0.000231          NaN          NaN
# 83  (2023, 18:31:00, 14, BTC, 0.00034)    0.000136          NaN          NaN
# 84  (2023, 18:21:00, 14, BTC, 0.00033)    0.000330          NaN          NaN
#
# [85 rows x 14 columns]

# %%
df.to_csv('../Output/CLEAN_data_10-11-2023.csv',index=False)
df.to_csv('../Output/BackUpMainFiles/CLEAN_data_10-11-2023.csv',index=False)
# adaDf.to_csv('../Output/ADA_clean_data_12-20-2022.csv')
# btcDf.to_csv('../Output/BTC_clean_data_12-20-2022.csv')
# ethDf.to_csv('../Output/ETH_clean_data_12-20-2022.csv')
# dotDf.to_csv('../Output/Dot_clean_data_12-20-2022.csv')
# solDf.to_csv('../Output/Sol_clean_data_12-20-2022.csv')
# roseDf.to_csv('../Output/Rose_clean_data_12-20-2022.csv')
# bnbDf.to_csv('../Output/BNB_clean_data_12-20-2022.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 2
#       1 df.to_csv('../Output/CLEAN_data_10-11-2023.csv',index=False)
# ----> 2 df.to_csv('..Output/BackUpMainFiles/CLEAN_data_10-11-2023.csv',index=False)
#       3 # adaDf.to_csv('../Output/ADA_clean_data_12-20-2022.csv')
#       4 # btcDf.to_csv('../Output/BTC_clean_data_12-20-2022.csv')
#       5 # ethDf.to_csv('../Output/ETH_clean_data_12-20-2022.csv')
#    (...)
#       8 # roseDf.to_csv('../Output/Rose_clean_data_12-20-2022.csv')
#       9 # bnbDf.to_csv('../Output/BNB_clean_data_12-20-2022.csv')
#
# File ~\.pyenv\pyenv-win\versions\3.9.0\lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File ~\.pyenv\pyenv-win\versions\3.9.0\lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File ~\.pyenv\pyenv-win\versions\3.9.0\lib\site-packages\pandas\io\formats\csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File ~\.pyenv\pyenv-win\versions\3.9.0\lib\site-packages\pandas\io\common.py:739, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     737 # Only for write methods
#     738 if "r" not in mode and is_path:
# --> 739     check_parent_directory(str(handle))
#     741 if compression:
#     742     if compression != "zstd":
#     743         # compression libraries do not like an explicit text-mode
#
# File ~\.pyenv\pyenv-win\versions\3.9.0\lib\site-packages\pandas\io\common.py:604, in check_parent_directory(path)
#     602 parent = Path(path).parent
#     603 if not parent.is_dir():
# --> 604     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..Output\BackUpMainFiles'
